# %%
import pandas as pd

df = pd.read_csv("gold.csv")
df

# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Create Year, Month, Day columns
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# Create Volatility column
df['Volatility'] = df['High'] - df['Low']

# Remove unwanted column if present
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])

# Save Tableau-ready CSV
df.to_csv("gold_tableau.csv", index=False)

# Verify output
print("Columns:")
print(df.columns)

print("\nTotal Rows:", len(df))
print("\nFile created successfully: gold_tableau.csv")
# Out:
# Columns:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Currency', 'Year',
#        'Month', 'Day', 'Volatility'],
#       dtype='object')
#
# Total Rows: 5703
#
# File created successfully: gold_tableau.csv
